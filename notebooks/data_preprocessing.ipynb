# %% [markdown]
# # Data Preprocessing and EDA

# %%
# import basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, sys
import warnings
warnings.filterwarnings('ignore')

# get working directory
sys.path.append(os.path.abspath('..'))

# %%
# get utilis
import scripts.data_preprocessing as dp

# %%
filepath ='../data/BrentOilprices.csv'
df = dp.load_dataset(filepath)
df.head()
# Out:
#         Date  Price
# 0 1987-05-20  18.63
# 1 1987-05-21  18.45
# 2 1987-05-22  18.55
# 3 1987-05-25  18.60
# 4 1987-05-26  18.63

# %%
# Summary statistics
dp.summary_statistics(df)
# Out:
# Summary Statistics:
#                                 Date        Price
# count                           9011  9011.000000
# mean   2005-02-10 23:46:53.760958720    48.420782
# min              1987-05-20 00:00:00     9.100000
# 25%              1996-03-20 12:00:00    19.050000
# 50%              2005-02-02 00:00:00    38.570000
# 75%              2014-01-09 12:00:00    70.090000
# max              2022-11-14 00:00:00   143.950000
# std                              NaN    32.860110
#
#
# Data information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9011 entries, 0 to 9010
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    9011 non-null   datetime64[ns]
#  1   Price   9011 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 140.9 KB
# None
#
#
# Check for missing value
# Date     0
# Price    0
# dtype: int64

# %% [markdown]
# Check skewness and kurtosis

# %%
# Check skewness and kurtosis
dp.sckewness_kurtosis(df)
# Out:
# Skewness: 0.7651771214933534
# Kurtosis: -0.6107670024223348

# %% [markdown]
# Stationary test

# %%
# Stationary test
dp.test_stationarity(df['Price'])
# Out:
# ADF Statistic: -1.9938560113924675
# p-value: 0.28927350489340287
# Critical Values: {'1%': np.float64(-3.4310783342658615), '5%': np.float64(-2.861861876398633), '10%': np.float64(-2.566941329781918)}

# %% [markdown]
# ## Visualizing

# %%
# Visualizing price trends
dp.price_trend(df)

# %%
# Rolling mean and standard deviation
dp.rolling_mean_std(df)

# %%
# Distribution plot
dp.distribution_plot(df)

# %%
# Box plot to detect outliers
dp.box_plot(df)
